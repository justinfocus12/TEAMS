# %% [markdown]
# # Demonstration of TEAMS software via example of Lorenz-96

# %% [markdown]
# ## Part 1: running the model freely

# %%
import numpy as np
import matplotlib.pyplot as plt
from importlib import reload
from pprint import pprint
import sys
import os

# %%
sys.path.append("../..")
import lorenz96; reload(lorenz96)
import forcing; reload(forcing)
import ensemble; reload(ensemble)
# Out:
# <module 'ensemble' from '/Users/justinfinkel/Documents/postdoc_mit/computing/TEAMS/examples/lorenz96/../../ensemble.py'>

# %%
cfg_ode = lorenz96.Lorenz96ODE.default_config()
pprint(cfg_ode)
# Out:
# {'F': 6.0,
#  'K': 40,
#  'dt_save': 0.01,
#  'dt_step': 0.001,
#  'frc': {'impulsive': {'site_magnitudes': [],
#                        'sites': [],
#                        'wavenumber_magnitudes': [0.01],
#                        'wavenumbers': [4]},
#          'type': 'impulsive'},
#  't_burnin_phys': 10.0}

# %%
ode = lorenz96.Lorenz96ODE(cfg_ode)

# %%
tp_init = 0.0
t_init = int(round(tp_init/ode.dt_save))
x_init = ode.generate_default_init_cond(t_init)
x_dt_init = ode.tendency(t_init, x_init)

# %%
fig,axes = plt.subplots(nrows=2,ncols=1,figsize=(12,8))
ax = axes[0]
ax.plot(np.arange(ode.K), x_init)
ax.set_ylabel(r"$x_k(t=0)$")
ax.set_xlabel(r"$k$")
ax = axes[1]
ax.plot(np.arange(ode.K), x_dt_init)
ax.set_ylabel(r"$\frac{dx_k}{dt}(t=0)$")
ax.set_xlabel(r"$k$")
# Out:
# Text(0.5, 0, '$k$')

# %% [markdown]
# Integrate for enough time to spin up away from the unstable equilibrium $x_0=x_1=...=x_K=F$, and reach statistical steady state.

# %%
tp_fin = 20.0
t_fin = int(round(tp_fin/ode.dt_save))
t_save,x_save = ode.run_trajectory_unperturbed(x_init, t_init, t_fin, "rk4")
tp_save = t_save * ode.dt_save
Nt_save = len(t_save)
# Out:
# x_save.shape = (2000, 40)

# %%
fig,ax = plt.subplots(figsize=(12,4))
handles = []
tps_plot = np.array([0.0, 6.0, 18.75, 19.0])
tidx_plot = ((tps_plot-tp_init)/ode.dt_save).astype(int)
for i_t in tidx_plot:
    h, = ax.plot(np.arange(ode.K), x_save[i_t], label=r"$t = %.2f$"%(tp_save[i_t]))
    handles.append(h)
ax.legend(handles=handles,bbox_to_anchor=(1,1),loc="upper left")
ax.set_xlabel(r"$k$")
ax.set_ylabel(r"$x_k(t)$")
# Out:
# Text(0, 0.5, '$x_k(t)$')

# %% [markdown]
# Visualize as a Hovmoller diagram

# %%
fig,ax = plt.subplots(figsize=(12,6))
img = ode.plot_hovmoller(t_save, x_save, fig, ax)
fig.colorbar(img, ax=ax, orientation="horizontal")
ax.set_xlabel(r"$t$")
ax.set_ylabel(r"$k$")
ax.set_title("$x_k(t)$")
# Out:
# Text(0.5, 1.0, '$x_k(t)$')

# %% [markdown]
# ## Part 2: running the model forced by white noise

# %%
cfg_sde = lorenz96.Lorenz96SDE.default_config()
cfg_sde['frc']['white']['wavenumber_magnitudes'][0] = 1.0
pprint(cfg_sde)
# Out:
# {'frc': {'type': 'white',
#          'white': {'site_magnitudes': [],
#                    'sites': [],
#                    'wavenumber_magnitudes': [1.0],
#                    'wavenumbers': [4]}},
#  'ode': {'F': 6.0,
#          'K': 40,
#          'dt_save': 0.01,
#          'dt_step': 0.001,
#          'frc': {'impulsive': {'site_magnitudes': [],
#                                'sites': [],
#                                'wavenumber_magnitudes': [0.01],
#                                'wavenumbers': [4]},
#                  'type': 'impulsive'},
#          't_burnin_phys': 10.0},
#  'seed_max': 100000,
#  'seed_min': 1000}

# %%
sde = lorenz96.Lorenz96SDE(cfg_sde)

# %%
init_seed = 49381
rng = np.random.default_rng(init_seed)
t_save,x_save = sde.run_trajectory_unperturbed(x_init, t_init, t_fin, "euler_maruyama", rng)
# Out:
# init_time = 0, fin_time = 2000
# Initializing output array...done
# done; integrating,...

# %%
fig,ax = plt.subplots(figsize=(12,6))
img = ode.plot_hovmoller(t_save, x_save, fig, ax)
fig.colorbar(img, ax=ax, orientation="horizontal")
ax.set_xlabel(r"$t$")
ax.set_ylabel(r"$k$")
ax.set_title("$x_k(t)$ stochastically forced")
# Out:
# Text(0.5, 1.0, '$x_k(t)$ stochastically forced')

# %% [markdown]
# ## Part 3: Perturb the system mid-integration by swapping in a new random number generator

# %% [markdown]
# The ```Forcing``` object is defined in the ```forcing``` module, and can take the form of (a) occasional finite-amplitude perturbations (```OccasionalVectorForcing```), occasional re-seeds of the white noise generator (```OccasionalReseedForcing```) or a combination (```SuperposedForcing```). Here we only do one occasional reseed for simplicity.

# %%
print(f'{ode.impulse_dim = }')
print(f'{ode.impulse_matrix = }')
# Out:
# ode.impulse_dim = 2
# ode.impulse_matrix = <40x2 sparse matrix of type '<class 'numpy.float64'>'
# 	with 79 stored elements in Compressed Sparse Row format>

# %%
rng_impulse = np.random.default_rng(seed=9823)
rng_reseed = 7856
root_dir = os.getcwd()
obs_fun = lambda t,x: x[:,0]

# %%
mid_pert = 0.01 * rng_impulse.normal(size=(ode.impulse_dim),)
reseed_forcing_null = forcing.OccasionalReseedForcing(t_init, t_fin, [], [])
reseed_forcing = forcing.OccasionalReseedForcing(t_init, t_fin, [(t_init+t_fin)//2], [rng_reseed])
vector_forcing_null = forcing.OccasionalVectorForcing(t_init, t_fin, [], [])
vector_forcing = forcing.OccasionalVectorForcing(t_init, t_fin, [(t_init+t_fin)//2], [mid_pert])

# %% [markdown]
# Apply two different kinds of perturbations: one purely impulsive, one purely reseeding

# %%
icandf_reseed = dict({
    "init_cond": x_init,
    "init_rngstate": np.random.default_rng(init_seed).bit_generator.state,
    "frc": forcing.SuperposedForcing([reseed_forcing,vector_forcing_null]),
})
saveinfo = dict({"filename": "x_pert_reseed.npz"})
metadata_reseed,x0_reseed = sde.run_trajectory(icandf_reseed, obs_fun, saveinfo, root_dir)
# Out:
# Before segment loop, using 17.520390144 GB
# Starting segment: 0, init_time = 0, fin_time = 1000.0
# Initializing output array...done
# done; integrating,...1, init_time = 1000.0, fin_time = 2000
# Initializing output array...done
# done; integrating,...
# Finished all segments
# After segment loop, using 17.549262848 GB
# After collecting garbage, using 17.549381632 GB

# %%
icandf_impulse = dict({
    "init_cond": x_init,
    "init_rngstate": np.random.default_rng(init_seed).bit_generator.state,
    "frc": forcing.SuperposedForcing([reseed_forcing_null,vector_forcing]),
})
saveinfo = dict({"filename": "x_pert_impulse.npz"})
metadata_reseed,x0_impulse = sde.run_trajectory(icandf_impulse, obs_fun, saveinfo, root_dir)
# Out:
# Before segment loop, using 17.523441664 GB
# Starting segment: 0, init_time = 0, fin_time = 1000.0
# Initializing output array...done
# done; integrating,...1, init_time = 1000.0, fin_time = 2000
# Initializing output array...done
# done; integrating,...
# Finished all segments
# After segment loop, using 17.537122304 GB
# After collecting garbage, using 17.537171456 GB

# %%
fig,axes = plt.subplots(figsize=(12,8), nrows=2, sharex=True)
ax = axes[0]
h_control, = ax.plot(t_save*ode.dt_save, x_save[:,0], color="black", linestyle="--", linewidth=3, label="Control")
h_reseed, = ax.plot(t_save*ode.dt_save, x0_reseed, color="red", linestyle="-", linewidth=1, label="Reseed")
h_impulse, = ax.plot(t_save*ode.dt_save, x0_impulse, color="dodgerblue", linestyle="-", linewidth=1, label="Impulse")
ax.axvline((t_init+t_fin)/2*ode.dt_save)
ax.legend(handles=[h_control,h_reseed,h_impulse], bbox_to_anchor=(1,1), loc="upper left")
ax.set_title(r"$x_0(t)$")
ax = axes[1]
h_reseed, = ax.plot(t_save*ode.dt_save, x0_reseed-x_save[:,0], 
                    color="red", linestyle="-", linewidth=1, label="Reseed $-$ Control")
h_impulse, = ax.plot(t_save*ode.dt_save, x0_impulse-x_save[:,0], 
                     color="dodgerblue", linestyle="-", linewidth=1, label="Impulse $-$ Control")
ax.axvline((t_init+t_fin)/2*ode.dt_save)
ax.legend(handles=[h_reseed,h_impulse], bbox_to_anchor=(1,1), loc="upper left")
ax.set_title(r"$x_0(t)-x_0^{\mathrm{control}}(t)$")
# Out:
# Text(0.5, 1.0, '$x_0(t)-x_0^{\\mathrm{control}}(t)$')

# %% [markdown]
# ## Part 4: Manage ensemble members through an Ensemble object

# %%
ens = ensemble.Ensemble(sde, root_dir=root_dir)
saveinfo_2 = dict({"filename": "x_perturbed_in_ensemble.npz"})
ens.branch_or_plant(icandf, obs_fun, saveinfo, parent=None)
# Out:
# Before segment loop, using 2.026381312 GB
# Starting segment: 0, init_time = 0, fin_time = 1000.0
# Initializing output array...done
# done; integrating,...1, init_time = 1000.0, fin_time = 2000
# Initializing output array...done
# done; integrating,...
# Finished all segments
# After segment loop, using 2.02625024 GB
# After collecting garbage, using 2.026061824 GB
# array([ 6.15102582,  6.29741339,  6.33557406, ...,  0.01435829,
#        -0.11141354, -0.23038063])

# %% [markdown]
# ## Part 5: Define a rule for growing an ensemble through an Algorithm object
